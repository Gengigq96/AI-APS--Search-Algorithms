# %% [markdown]
# # Actividad :  Resolución de problema mediante búsqueda heurística

# %%
# !pip install simpleai flask pydot graphviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: simpleai in c:\users\genispc\appdata\roaming\python\python311\site-packages (0.8.3)
# Requirement already satisfied: flask in c:\programdata\anaconda3\lib\site-packages (2.2.5)
# Requirement already satisfied: pydot in c:\users\genispc\appdata\roaming\python\python311\site-packages (2.0.0)
# Requirement already satisfied: graphviz in c:\users\genispc\appdata\roaming\python\python311\site-packages (0.20.3)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\programdata\anaconda3\lib\site-packages (from flask) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\programdata\anaconda3\lib\site-packages (from flask) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\programdata\anaconda3\lib\site-packages (from flask) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\programdata\anaconda3\lib\site-packages (from flask) (8.1.7)
# Requirement already satisfied: pyparsing>=3 in c:\programdata\anaconda3\lib\site-packages (from pydot) (3.0.9)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click>=8.0->flask) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from Jinja2>=3.0->flask) (2.1.3)

# %%
# NOTA: WebViewer sólo funcionará si ejecutáis en modo local

from __future__ import print_function

import math
from simpleai.search.viewers import BaseViewer,ConsoleViewer,WebViewer
from simpleai.search import SearchProblem, astar, breadth_first, depth_first, uniform_cost



class GameWalkPuzzle(SearchProblem):

    def __init__(self, board, costs, heuristic_number):
        self.board = board
        self.goal = (0, 0)
        self.costs = costs
        self.heuristic_number = heuristic_number
        for y in range(len(self.board)):
            for x in range(len(self.board[y])):
                if self.board[y][x].lower() == "t":
                    self.initial = (x, y)
                elif self.board[y][x].lower() == "p":
                    self.goal = (x, y)

        super(GameWalkPuzzle, self).__init__(initial_state=self.initial)

    def actions(self, state):
        actions = []
        for action in list(self.costs.keys()):
            newx, newy = self.result(state, action)
            if self.board[newy][newx] != "#":
                actions.append(action)
        return actions

    def result(self, state, action):
        x, y = state

        if action.count("up"):
            y -= 1
        if action.count("down"):
            y += 1
        if action.count("left"):
            x -= 1
        if action.count("right"):
            x += 1

        new_state = (x, y)
        return new_state

    def is_goal(self, state):
        return state == self.goal

    def cost(self, state, action, state2):
        return self.costs[action]

    # Esta función heurística es la distancia entre el estado actual
    # el objetivo (único) identificado como self.goal
    def heuristic1(self, state):
        x, y = state
        gx, gy = self.goal
        return abs(x - gx) + abs(y - gy)

    def heuristic2(self, state):
        x, y = state
        gx, gy = self.goal
        return max(abs(x - gx),abs(y - gy))

    def heuristic3(self, state):
        x, y = state
        gx, gy = self.goal
        return 2*(abs(x - gx) + abs(y - gy))

    def heuristic(self,state):
      if self.heuristic_number == 1:
          return self.heuristic1(state)
      elif self.heuristic_number == 2:
          return self.heuristic2(state)
      elif self.heuristic_number == 3:
          return self.heuristic3(state)
      else:
        raise Exception("El número de la función heurística debe estar entre 1 y 3. Revise la inicialización del problema.")

def searchInfo (problem,result,use_viewer):
    def getTotalCost (problem,result):
        originState = problem.initial_state
        totalCost = 0
        for action,endingState in result.path():
            if action is not None:
                totalCost += problem.cost(originState,action,endingState)
                originState = endingState
        return totalCost


    res = "Total length of solution: {0}\n".format(len(result.path()))
    res += "Total cost of solution: {0}\n".format(getTotalCost(problem,result))

    if use_viewer:
        stats = [{'name': stat.replace('_', ' '), 'value': value}
                         for stat, value in list(use_viewer.stats.items())]

        for s in stats:
            res+= '{0}: {1}\n'.format(s['name'],s['value'])
    return res


def resultado_experimento(problem,MAP,result,used_viewer):
    path = [x[1] for x in result.path()]

    for y in range(len(MAP)):
        for x in range(len(MAP[y])):
            if (x, y) == problem.initial:
                print("T", end='')
            elif (x, y) == problem.goal:
                print("P", end='')
            elif (x, y) in path:
                print("·", end='')
            else:
                print(MAP[y][x], end='')
        print()

    info=searchInfo(problem,result,used_viewer)
    print(info)

def main(MAP_ASCII,COSTS,algorithms,heuristic_number=1):
    MAP = [list(x) for x in MAP_ASCII.split("\n") if x]

    for algorithm in algorithms:
      problem = GameWalkPuzzle(MAP,COSTS,heuristic_number)
      used_viewer=ConsoleViewer()
      # Probad también ConsoleViewer para depurar   BaseViewer
      # No podréis usar WebViewer en Collab para ver los árboles

      # Mostramos tres experimentos
      print ("Experimento con algoritmo {}:".format(algorithm))

      result = algorithm(problem, graph_search=True,viewer=used_viewer)
      resultado_experimento(problem,MAP,result,used_viewer)

# %%
# Se ejecutan los algoritmos de búsqueda en amplitud y búsqueda en profundidad

MAP_ASCII = """
########
#    P #
# #### #
#  T # #
# ##   #
#      #
########
"""

COSTS = {
    "up": 1.0,
    "down": 1.0, 
    "right": 1.0, 
    "left": 1.0,  
}

algorithms=(breadth_first,depth_first)
main (MAP_ASCII,COSTS,algorithms)
# Out:
# Experimento con algoritmo <function breadth_first at 0x000001E4E3FDC900>:
# After each step, a prompt will be shown.
# On the prompt, you can just press Enter to continue to the next step.
# But you can also have this commands:
# (write the command you want to use and then press Enter)
# * h: get help.
# * g PATH_TO_PNG_IMAGE: create png with graph of the current state.
# * e: run non-interactively to the end of the algorithm.
# * s: show statistics of the execution (max fringe size, visited nodes).
# * q: quit program.
# EVENT: started
# Algorithm just started.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 26
#      18 COSTS = {
#      19     "up": 1.0,
#      20     "down": 1.0,
#      21     "right": 1.0,
#      22     "left": 1.0,
#      23 }
#      25 algorithms=(breadth_first,depth_first)
# ---> 26 main (MAP_ASCII,COSTS,algorithms)
#
# Cell In[3], line 142, in main(MAP_ASCII, COSTS, algorithms, heuristic_number)
#     136 # Probad también ConsoleViewer para depurar   BaseViewer
#     137 # No podréis usar WebViewer en Collab para ver los árboles
#     138
#     139 # Mostramos tres experimentos
#     140 print ("Experimento con algoritmo {}:".format(algorithm))
# --> 142 result = algorithm(problem, graph_search=True,viewer=used_viewer)
#     143 resultado_experimento(problem,MAP,result,used_viewer)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\simpleai\search\traditional.py:16, in breadth_first(problem, graph_search, viewer)
#       8 def breadth_first(problem, graph_search=False, viewer=None):
#       9     '''
#      10     Breadth first search.
#      11
#    (...)
#      14     SearchProblem.is_goal.
#      15     '''
# ---> 16     return _search(problem,
#      17                    FifoList(),
#      18                    graph_search=graph_search,
#      19                    viewer=viewer)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\simpleai\search\traditional.py:131, in _search(problem, fringe, graph_search, depth_limit, node_factory, graph_replace_when_better, viewer)
#     127 '''
#     128 Basic search algorithm, base of all the other search algorithms.
#     129 '''
#     130 if viewer:
# --> 131     viewer.event('started')
#     133 memory = set()
#     134 initial_node = node_factory(state=problem.initial_state,
#     135                             problem=problem)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\simpleai\search\viewers.py:235, in ConsoleViewer.event(self, name, *params)
#     232 self.output('EVENT: %s' % self.last_event.name)
#     233 self.output(self.last_event.description)
# --> 235 self.pause()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\simpleai\search\viewers.py:241, in ConsoleViewer.pause(self)
#     239 while prompt and self.interactive:
#     240     prompt = False
# --> 241     option = input('> ').strip()
#     242     if option:
#     243         if option == 'h':
#
# File c:\ProgramData\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1262, in Kernel.raw_input(self, prompt)
#    1260     msg = "raw_input was called, but this frontend does not support input requests."
#    1261     raise StdinNotImplementedError(msg)
# -> 1262 return self._input_request(
#    1263     str(prompt),
#    1264     self._parent_ident["shell"],
#    1265     self.get_parent("shell"),
#    1266     password=False,
#    1267 )
#
# File c:\ProgramData\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1305, in Kernel._input_request(self, prompt, ident, parent, password)
#    1302 except KeyboardInterrupt:
#    1303     # re-raise KeyboardInterrupt, to truncate traceback
#    1304     msg = "Interrupted by user"
# -> 1305     raise KeyboardInterrupt(msg) from None
#    1306 except Exception:
#    1307     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# Se utiliza el mismo mapa pero se varían los costes

MAP_ASCII = """
########
#    P #
# #### #
#  T # #
# ##   #
#      #
########
"""

COSTS = {
    "up": 5.0,
    "down": 5.0,
    "right": 2.0,
    "left": 2.0,
}

algorithms=(breadth_first,uniform_cost,astar)
main (MAP_ASCII,COSTS,algorithms)
# Out:
# Experimento con algoritmo <function breadth_first at 0x000001E20547DBC0>:
# After each step, a prompt will be shown.
# On the prompt, you can just press Enter to continue to the next step.
# But you can also have this commands:
# (write the command you want to use and then press Enter)
# * h: get help.
# * g PATH_TO_PNG_IMAGE: create png with graph of the current state.
# * e: run non-interactively to the end of the algorithm.
# * s: show statistics of the execution (max fringe size, visited nodes).
# * q: quit program.
# EVENT: started
# Algorithm just started.
# EVENT: new_iteration
# New iteration with 1 elements in the fringe:
# [Node <(3, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(3, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(3, 3)>]
# Successors: [[Node <(4, 3)>, Node <(2, 3)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(4, 3)>, Node <(2, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(4, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(4, 3)>]
# Successors: [[Node <(4, 4)>, Node <(3, 3)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(2, 3)>, Node <(4, 4)>]
# EVENT: chosen_node
# Chosen node: Node <(2, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(2, 3)>]
# Successors: [[Node <(3, 3)>, Node <(1, 3)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(4, 4)>, Node <(1, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(4, 4)>
# Not goal
# EVENT: expanded
# Expanded [Node <(4, 4)>]
# Successors: [[Node <(4, 3)>, Node <(4, 5)>, Node <(5, 4)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(1, 3)>, Node <(4, 5)>, Node <(5, 4)>]
# EVENT: chosen_node
# Chosen node: Node <(1, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(1, 3)>]
# Successors: [[Node <(1, 2)>, Node <(1, 4)>, Node <(2, 3)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(4, 5)>, Node <(5, 4)>, Node <(1, 2)>, Node <(1, 4)>]
# EVENT: chosen_node
# Chosen node: Node <(4, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(4, 5)>]
# Successors: [[Node <(4, 4)>, Node <(5, 5)>, Node <(3, 5)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(5, 4)>, Node <(1, 2)>, Node <(1, 4)>, Node <(5, 5)>, Node <(3, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(5, 4)>
# Not goal
# EVENT: expanded
# Expanded [Node <(5, 4)>]
# Successors: [[Node <(5, 5)>, Node <(6, 4)>, Node <(4, 4)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(1, 2)>, Node <(1, 4)>, Node <(5, 5)>, Node <(3, 5)>, Node <(6, 4)>]
# EVENT: chosen_node
# Chosen node: Node <(1, 2)>
# Not goal
# EVENT: expanded
# Expanded [Node <(1, 2)>]
# Successors: [[Node <(1, 1)>, Node <(1, 3)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(1, 4)>, Node <(5, 5)>, Node <(3, 5)>, Node <(6, 4)>, Node <(1, 1)>]
# EVENT: chosen_node
# Chosen node: Node <(1, 4)>
# Not goal
# EVENT: expanded
# Expanded [Node <(1, 4)>]
# Successors: [[Node <(1, 3)>, Node <(1, 5)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(5, 5)>, Node <(3, 5)>, Node <(6, 4)>, Node <(1, 1)>, Node <(1, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(5, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(5, 5)>]
# Successors: [[Node <(5, 4)>, Node <(6, 5)>, Node <(4, 5)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(3, 5)>, Node <(6, 4)>, Node <(1, 1)>, Node <(1, 5)>, Node <(6, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(3, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(3, 5)>]
# Successors: [[Node <(4, 5)>, Node <(2, 5)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(6, 4)>, Node <(1, 1)>, Node <(1, 5)>, Node <(6, 5)>, Node <(2, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 4)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 4)>]
# Successors: [[Node <(6, 3)>, Node <(6, 5)>, Node <(5, 4)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(1, 1)>, Node <(1, 5)>, Node <(6, 5)>, Node <(2, 5)>, Node <(6, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(1, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(1, 1)>]
# Successors: [[Node <(1, 2)>, Node <(2, 1)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(1, 5)>, Node <(6, 5)>, Node <(2, 5)>, Node <(6, 3)>, Node <(2, 1)>]
# EVENT: chosen_node
# Chosen node: Node <(1, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(1, 5)>]
# Successors: [[Node <(1, 4)>, Node <(2, 5)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(6, 5)>, Node <(2, 5)>, Node <(6, 3)>, Node <(2, 1)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 5)>]
# Successors: [[Node <(6, 4)>, Node <(5, 5)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(2, 5)>, Node <(6, 3)>, Node <(2, 1)>]
# EVENT: chosen_node
# Chosen node: Node <(2, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(2, 5)>]
# Successors: [[Node <(3, 5)>, Node <(1, 5)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(6, 3)>, Node <(2, 1)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 3)>]
# Successors: [[Node <(6, 2)>, Node <(6, 4)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(2, 1)>, Node <(6, 2)>]
# EVENT: chosen_node
# Chosen node: Node <(2, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(2, 1)>]
# Successors: [[Node <(3, 1)>, Node <(1, 1)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(6, 2)>, Node <(3, 1)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 2)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 2)>]
# Successors: [[Node <(6, 1)>, Node <(6, 3)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(3, 1)>, Node <(6, 1)>]
# EVENT: chosen_node
# Chosen node: Node <(3, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(3, 1)>]
# Successors: [[Node <(4, 1)>, Node <(2, 1)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(6, 1)>, Node <(4, 1)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 1)>]
# Successors: [[Node <(6, 2)>, Node <(5, 1)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(4, 1)>, Node <(5, 1)>]
# EVENT: chosen_node
# Chosen node: Node <(4, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(4, 1)>]
# Successors: [[Node <(5, 1)>, Node <(3, 1)>]]
# EVENT: new_iteration
# New iteration with 1 elements in the fringe:
# [Node <(5, 1)>]
# EVENT: chosen_node
# Chosen node: Node <(5, 1)>
# Is goal!
# EVENT: finished
# Finished algorithm returning Node <(5, 1)>.
# Solution type: goal found
# Path from initial to goal: [(None, (3, 3)), ('right', (4, 3)), ('down', (4, 4)), ('right', (5, 4)), ('right', (6, 4)), ('up', (6, 3)), ('up', (6, 2)), ('up', (6, 1)), ('left', (5, 1))]
# ########
# #    P·#
# # ####·#
# #  T·#·#
# # ##···#
# #      #
# ########
# Total length of solution: 9
# Total cost of solution: 28.0
# max fringe size: 5
# visited nodes: 23
# iterations: 23
#
# Experimento con algoritmo <function uniform_cost at 0x000001E20547FD80>:
# After each step, a prompt will be shown.
# On the prompt, you can just press Enter to continue to the next step.
# But you can also have this commands:
# (write the command you want to use and then press Enter)
# * h: get help.
# * g PATH_TO_PNG_IMAGE: create png with graph of the current state.
# * e: run non-interactively to the end of the algorithm.
# * s: show statistics of the execution (max fringe size, visited nodes).
# * q: quit program.
# EVENT: started
# Algorithm just started.
# EVENT: new_iteration
# New iteration with 1 elements in the fringe:
# [Node <(3, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(3, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(3, 3)>]
# Successors: [[Node <(4, 3)>, Node <(2, 3)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(4, 3)>, Node <(2, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(4, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(4, 3)>]
# Successors: [[Node <(4, 4)>, Node <(3, 3)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(2, 3)>, Node <(4, 4)>]
# EVENT: chosen_node
# Chosen node: Node <(2, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(2, 3)>]
# Successors: [[Node <(3, 3)>, Node <(1, 3)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(1, 3)>, Node <(4, 4)>]
# EVENT: chosen_node
# Chosen node: Node <(1, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(1, 3)>]
# Successors: [[Node <(1, 2)>, Node <(1, 4)>, Node <(2, 3)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(4, 4)>, Node <(1, 2)>, Node <(1, 4)>]
# EVENT: chosen_node
# Chosen node: Node <(4, 4)>
# Not goal
# EVENT: expanded
# Expanded [Node <(4, 4)>]
# Successors: [[Node <(4, 3)>, Node <(4, 5)>, Node <(5, 4)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(1, 2)>, Node <(1, 4)>, Node <(5, 4)>, Node <(4, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(1, 2)>
# Not goal
# EVENT: expanded
# Expanded [Node <(1, 2)>]
# Successors: [[Node <(1, 1)>, Node <(1, 3)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(1, 4)>, Node <(5, 4)>, Node <(4, 5)>, Node <(1, 1)>]
# EVENT: chosen_node
# Chosen node: Node <(1, 4)>
# Not goal
# EVENT: expanded
# Expanded [Node <(1, 4)>]
# Successors: [[Node <(1, 3)>, Node <(1, 5)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(5, 4)>, Node <(4, 5)>, Node <(1, 1)>, Node <(1, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(5, 4)>
# Not goal
# EVENT: expanded
# Expanded [Node <(5, 4)>]
# Successors: [[Node <(5, 5)>, Node <(6, 4)>, Node <(4, 4)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(6, 4)>, Node <(4, 5)>, Node <(1, 5)>, Node <(5, 5)>, Node <(1, 1)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 4)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 4)>]
# Successors: [[Node <(6, 3)>, Node <(6, 5)>, Node <(5, 4)>]]
# EVENT: new_iteration
# New iteration with 6 elements in the fringe:
# [Node <(4, 5)>, Node <(5, 5)>, Node <(1, 5)>, Node <(1, 1)>, Node <(6, 3)>, Node <(6, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(4, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(4, 5)>]
# Successors: [[Node <(4, 4)>, Node <(5, 5)>, Node <(3, 5)>]]
# EVENT: new_iteration
# New iteration with 6 elements in the fringe:
# [Node <(1, 5)>, Node <(5, 5)>, Node <(3, 5)>, Node <(1, 1)>, Node <(6, 3)>, Node <(6, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(1, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(1, 5)>]
# Successors: [[Node <(1, 4)>, Node <(2, 5)>]]
# EVENT: new_iteration
# New iteration with 6 elements in the fringe:
# [Node <(3, 5)>, Node <(5, 5)>, Node <(1, 1)>, Node <(6, 5)>, Node <(6, 3)>, Node <(2, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(3, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(3, 5)>]
# Successors: [[Node <(4, 5)>, Node <(2, 5)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(5, 5)>, Node <(1, 1)>, Node <(6, 5)>, Node <(2, 5)>, Node <(6, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(5, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(5, 5)>]
# Successors: [[Node <(5, 4)>, Node <(6, 5)>, Node <(4, 5)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(1, 1)>, Node <(2, 5)>, Node <(6, 5)>, Node <(6, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(1, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(1, 1)>]
# Successors: [[Node <(1, 2)>, Node <(2, 1)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(6, 5)>, Node <(2, 5)>, Node <(6, 3)>, Node <(2, 1)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 5)>]
# Successors: [[Node <(6, 4)>, Node <(5, 5)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(6, 3)>, Node <(2, 5)>, Node <(2, 1)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 3)>]
# Successors: [[Node <(6, 2)>, Node <(6, 4)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(2, 5)>, Node <(2, 1)>, Node <(6, 2)>]
# EVENT: chosen_node
# Chosen node: Node <(2, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(2, 5)>]
# Successors: [[Node <(3, 5)>, Node <(1, 5)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(2, 1)>, Node <(6, 2)>]
# EVENT: chosen_node
# Chosen node: Node <(2, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(2, 1)>]
# Successors: [[Node <(3, 1)>, Node <(1, 1)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(3, 1)>, Node <(6, 2)>]
# EVENT: chosen_node
# Chosen node: Node <(3, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(3, 1)>]
# Successors: [[Node <(4, 1)>, Node <(2, 1)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(4, 1)>, Node <(6, 2)>]
# EVENT: chosen_node
# Chosen node: Node <(4, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(4, 1)>]
# Successors: [[Node <(5, 1)>, Node <(3, 1)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(6, 2)>, Node <(5, 1)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 2)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 2)>]
# Successors: [[Node <(6, 1)>, Node <(6, 3)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(5, 1)>, Node <(6, 1)>]
# EVENT: chosen_node
# Chosen node: Node <(5, 1)>
# Is goal!
# EVENT: finished
# Finished algorithm returning Node <(5, 1)>.
# Solution type: goal found
# Path from initial to goal: [(None, (3, 3)), ('left', (2, 3)), ('left', (1, 3)), ('up', (1, 2)), ('up', (1, 1)), ('right', (2, 1)), ('right', (3, 1)), ('right', (4, 1)), ('right', (5, 1))]
# ########
# #····P #
# #·#### #
# #··T # #
# # ##   #
# #      #
# ########
# Total length of solution: 9
# Total cost of solution: 22.0
# max fringe size: 6
# visited nodes: 22
# iterations: 22
#
# Experimento con algoritmo <function astar at 0x000001E20547FEC0>:
# After each step, a prompt will be shown.
# On the prompt, you can just press Enter to continue to the next step.
# But you can also have this commands:
# (write the command you want to use and then press Enter)
# * h: get help.
# * g PATH_TO_PNG_IMAGE: create png with graph of the current state.
# * e: run non-interactively to the end of the algorithm.
# * s: show statistics of the execution (max fringe size, visited nodes).
# * q: quit program.
# EVENT: started
# Algorithm just started.
# EVENT: new_iteration
# New iteration with 1 elements in the fringe:
# [Node <(3, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(3, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(3, 3)>]
# Successors: [[Node <(4, 3)>, Node <(2, 3)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(4, 3)>, Node <(2, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(4, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(4, 3)>]
# Successors: [[Node <(4, 4)>, Node <(3, 3)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(2, 3)>, Node <(4, 4)>]
# EVENT: chosen_node
# Chosen node: Node <(2, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(2, 3)>]
# Successors: [[Node <(3, 3)>, Node <(1, 3)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(1, 3)>, Node <(4, 4)>]
# EVENT: chosen_node
# Chosen node: Node <(1, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(1, 3)>]
# Successors: [[Node <(1, 2)>, Node <(1, 4)>, Node <(2, 3)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(4, 4)>, Node <(1, 2)>, Node <(1, 4)>]
# EVENT: chosen_node
# Chosen node: Node <(4, 4)>
# Not goal
# EVENT: expanded
# Expanded [Node <(4, 4)>]
# Successors: [[Node <(4, 3)>, Node <(4, 5)>, Node <(5, 4)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(5, 4)>, Node <(1, 2)>, Node <(1, 4)>, Node <(4, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(5, 4)>
# Not goal
# EVENT: expanded
# Expanded [Node <(5, 4)>]
# Successors: [[Node <(5, 5)>, Node <(6, 4)>, Node <(4, 4)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(1, 2)>, Node <(6, 4)>, Node <(1, 4)>, Node <(4, 5)>, Node <(5, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(1, 2)>
# Not goal
# EVENT: expanded
# Expanded [Node <(1, 2)>]
# Successors: [[Node <(1, 1)>, Node <(1, 3)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(6, 4)>, Node <(1, 4)>, Node <(4, 5)>, Node <(5, 5)>, Node <(1, 1)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 4)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 4)>]
# Successors: [[Node <(6, 3)>, Node <(6, 5)>, Node <(5, 4)>]]
# EVENT: new_iteration
# New iteration with 6 elements in the fringe:
# [Node <(1, 4)>, Node <(4, 5)>, Node <(5, 5)>, Node <(1, 1)>, Node <(6, 3)>, Node <(6, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(1, 4)>
# Not goal
# EVENT: expanded
# Expanded [Node <(1, 4)>]
# Successors: [[Node <(1, 3)>, Node <(1, 5)>]]
# EVENT: new_iteration
# New iteration with 6 elements in the fringe:
# [Node <(4, 5)>, Node <(5, 5)>, Node <(1, 1)>, Node <(6, 3)>, Node <(6, 5)>, Node <(1, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(4, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(4, 5)>]
# Successors: [[Node <(4, 4)>, Node <(5, 5)>, Node <(3, 5)>]]
# EVENT: new_iteration
# New iteration with 6 elements in the fringe:
# [Node <(5, 5)>, Node <(1, 1)>, Node <(6, 3)>, Node <(3, 5)>, Node <(6, 5)>, Node <(1, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(5, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(5, 5)>]
# Successors: [[Node <(5, 4)>, Node <(6, 5)>, Node <(4, 5)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(1, 1)>, Node <(6, 3)>, Node <(3, 5)>, Node <(6, 5)>, Node <(1, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(1, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(1, 1)>]
# Successors: [[Node <(1, 2)>, Node <(2, 1)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(6, 3)>, Node <(2, 1)>, Node <(3, 5)>, Node <(6, 5)>, Node <(1, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 3)>]
# Successors: [[Node <(6, 2)>, Node <(6, 4)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(2, 1)>, Node <(3, 5)>, Node <(6, 5)>, Node <(1, 5)>, Node <(6, 2)>]
# EVENT: chosen_node
# Chosen node: Node <(2, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(2, 1)>]
# Successors: [[Node <(3, 1)>, Node <(1, 1)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(3, 5)>, Node <(3, 1)>, Node <(6, 5)>, Node <(1, 5)>, Node <(6, 2)>]
# EVENT: chosen_node
# Chosen node: Node <(3, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(3, 5)>]
# Successors: [[Node <(4, 5)>, Node <(2, 5)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(3, 1)>, Node <(6, 5)>, Node <(1, 5)>, Node <(6, 2)>, Node <(2, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(3, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(3, 1)>]
# Successors: [[Node <(4, 1)>, Node <(2, 1)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(6, 5)>, Node <(4, 1)>, Node <(1, 5)>, Node <(6, 2)>, Node <(2, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 5)>]
# Successors: [[Node <(6, 4)>, Node <(5, 5)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(4, 1)>, Node <(1, 5)>, Node <(6, 2)>, Node <(2, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(4, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(4, 1)>]
# Successors: [[Node <(5, 1)>, Node <(3, 1)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(1, 5)>, Node <(5, 1)>, Node <(6, 2)>, Node <(2, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(1, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(1, 5)>]
# Successors: [[Node <(1, 4)>, Node <(2, 5)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(5, 1)>, Node <(2, 5)>, Node <(6, 2)>]
# EVENT: chosen_node
# Chosen node: Node <(5, 1)>
# Is goal!
# EVENT: finished
# Finished algorithm returning Node <(5, 1)>.
# Solution type: goal found
# Path from initial to goal: [(None, (3, 3)), ('left', (2, 3)), ('left', (1, 3)), ('up', (1, 2)), ('up', (1, 1)), ('right', (2, 1)), ('right', (3, 1)), ('right', (4, 1)), ('right', (5, 1))]
# ########
# #····P #
# #·#### #
# #··T # #
# # ##   #
# #      #
# ########
# Total length of solution: 9
# Total cost of solution: 22.0
# max fringe size: 6
# visited nodes: 20
# iterations: 20

# %%
# Se utiliza el mismo mapa y se usan diferentes heurísticas

MAP_ASCII = """
########
#    P #
# #### #
#  T # #
# ##   #
#      #
########
"""

COSTS = {
    "up": 1.0,
    "down": 1.0,
    "right": 1.0,
    "left": 1.0,
}

algorithms=(astar,)
main (MAP_ASCII,COSTS,algorithms,1)
main (MAP_ASCII,COSTS,algorithms,2)
main (MAP_ASCII,COSTS,algorithms,3)
# Out:
# Experimento con algoritmo <function astar at 0x000001E4E51A9F80>:
# After each step, a prompt will be shown.
# On the prompt, you can just press Enter to continue to the next step.
# But you can also have this commands:
# (write the command you want to use and then press Enter)
# * h: get help.
# * g PATH_TO_PNG_IMAGE: create png with graph of the current state.
# * e: run non-interactively to the end of the algorithm.
# * s: show statistics of the execution (max fringe size, visited nodes).
# * q: quit program.
# EVENT: started
# Algorithm just started.
# EVENT: new_iteration
# New iteration with 1 elements in the fringe:
# [Node <(3, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(3, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(3, 3)>]
# Successors: [[Node <(4, 3)>, Node <(2, 3)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(4, 3)>, Node <(2, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(4, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(4, 3)>]
# Successors: [[Node <(4, 4)>, Node <(3, 3)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(2, 3)>, Node <(4, 4)>]
# EVENT: chosen_node
# Chosen node: Node <(2, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(2, 3)>]
# Successors: [[Node <(3, 3)>, Node <(1, 3)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(4, 4)>, Node <(1, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(4, 4)>
# Not goal
# EVENT: expanded
# Expanded [Node <(4, 4)>]
# Successors: [[Node <(4, 3)>, Node <(4, 5)>, Node <(5, 4)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(5, 4)>, Node <(4, 5)>, Node <(1, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(5, 4)>
# Not goal
# EVENT: expanded
# Expanded [Node <(5, 4)>]
# Successors: [[Node <(5, 5)>, Node <(6, 4)>, Node <(4, 4)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(4, 5)>, Node <(1, 3)>, Node <(5, 5)>, Node <(6, 4)>]
# EVENT: chosen_node
# Chosen node: Node <(4, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(4, 5)>]
# Successors: [[Node <(4, 4)>, Node <(5, 5)>, Node <(3, 5)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(5, 5)>, Node <(1, 3)>, Node <(6, 4)>, Node <(3, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(5, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(5, 5)>]
# Successors: [[Node <(5, 4)>, Node <(6, 5)>, Node <(4, 5)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(6, 4)>, Node <(1, 3)>, Node <(3, 5)>, Node <(6, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 4)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 4)>]
# Successors: [[Node <(6, 3)>, Node <(6, 5)>, Node <(5, 4)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(1, 3)>, Node <(6, 3)>, Node <(3, 5)>, Node <(6, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(1, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(1, 3)>]
# Successors: [[Node <(1, 2)>, Node <(1, 4)>, Node <(2, 3)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(6, 3)>, Node <(1, 2)>, Node <(3, 5)>, Node <(6, 5)>, Node <(1, 4)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 3)>]
# Successors: [[Node <(6, 2)>, Node <(6, 4)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(1, 2)>, Node <(6, 2)>, Node <(3, 5)>, Node <(1, 4)>, Node <(6, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(1, 2)>
# Not goal
# EVENT: expanded
# Expanded [Node <(1, 2)>]
# Successors: [[Node <(1, 1)>, Node <(1, 3)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(6, 2)>, Node <(1, 1)>, Node <(3, 5)>, Node <(6, 5)>, Node <(1, 4)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 2)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 2)>]
# Successors: [[Node <(6, 1)>, Node <(6, 3)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(1, 1)>, Node <(6, 1)>, Node <(3, 5)>, Node <(1, 4)>, Node <(6, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(1, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(1, 1)>]
# Successors: [[Node <(1, 2)>, Node <(2, 1)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(6, 1)>, Node <(2, 1)>, Node <(3, 5)>, Node <(6, 5)>, Node <(1, 4)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 1)>]
# Successors: [[Node <(6, 2)>, Node <(5, 1)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(2, 1)>, Node <(5, 1)>, Node <(3, 5)>, Node <(1, 4)>, Node <(6, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(2, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(2, 1)>]
# Successors: [[Node <(3, 1)>, Node <(1, 1)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(5, 1)>, Node <(3, 1)>, Node <(3, 5)>, Node <(6, 5)>, Node <(1, 4)>]
# EVENT: chosen_node
# Chosen node: Node <(5, 1)>
# Is goal!
# EVENT: finished
# Finished algorithm returning Node <(5, 1)>.
# Solution type: goal found
# Path from initial to goal: [(None, (3, 3)), ('right', (4, 3)), ('down', (4, 4)), ('right', (5, 4)), ('right', (6, 4)), ('up', (6, 3)), ('up', (6, 2)), ('up', (6, 1)), ('left', (5, 1))]
# ########
# #    P·#
# # ####·#
# #  T·#·#
# # ##···#
# #      #
# ########
# Total length of solution: 9
# Total cost of solution: 8.0
# max fringe size: 5
# visited nodes: 16
# iterations: 16
#
# Experimento con algoritmo <function astar at 0x000001E4E51A9F80>:
# After each step, a prompt will be shown.
# On the prompt, you can just press Enter to continue to the next step.
# But you can also have this commands:
# (write the command you want to use and then press Enter)
# * h: get help.
# * g PATH_TO_PNG_IMAGE: create png with graph of the current state.
# * e: run non-interactively to the end of the algorithm.
# * s: show statistics of the execution (max fringe size, visited nodes).
# * q: quit program.
# EVENT: started
# Algorithm just started.
# EVENT: new_iteration
# New iteration with 1 elements in the fringe:
# [Node <(3, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(3, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(3, 3)>]
# Successors: [[Node <(4, 3)>, Node <(2, 3)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(4, 3)>, Node <(2, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(4, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(4, 3)>]
# Successors: [[Node <(4, 4)>, Node <(3, 3)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(2, 3)>, Node <(4, 4)>]
# EVENT: chosen_node
# Chosen node: Node <(2, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(2, 3)>]
# Successors: [[Node <(3, 3)>, Node <(1, 3)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(4, 4)>, Node <(1, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(4, 4)>
# Not goal
# EVENT: expanded
# Expanded [Node <(4, 4)>]
# Successors: [[Node <(4, 3)>, Node <(4, 5)>, Node <(5, 4)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(1, 3)>, Node <(5, 4)>, Node <(4, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(1, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(1, 3)>]
# Successors: [[Node <(1, 2)>, Node <(1, 4)>, Node <(2, 3)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(5, 4)>, Node <(4, 5)>, Node <(1, 2)>, Node <(1, 4)>]
# EVENT: chosen_node
# Chosen node: Node <(5, 4)>
# Not goal
# EVENT: expanded
# Expanded [Node <(5, 4)>]
# Successors: [[Node <(5, 5)>, Node <(6, 4)>, Node <(4, 4)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(1, 2)>, Node <(4, 5)>, Node <(1, 4)>, Node <(6, 4)>, Node <(5, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(1, 2)>
# Not goal
# EVENT: expanded
# Expanded [Node <(1, 2)>]
# Successors: [[Node <(1, 1)>, Node <(1, 3)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(1, 4)>, Node <(4, 5)>, Node <(6, 4)>, Node <(5, 5)>, Node <(1, 1)>]
# EVENT: chosen_node
# Chosen node: Node <(1, 4)>
# Not goal
# EVENT: expanded
# Expanded [Node <(1, 4)>]
# Successors: [[Node <(1, 3)>, Node <(1, 5)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(6, 4)>, Node <(4, 5)>, Node <(1, 1)>, Node <(5, 5)>, Node <(1, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 4)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 4)>]
# Successors: [[Node <(6, 3)>, Node <(6, 5)>, Node <(5, 4)>]]
# EVENT: new_iteration
# New iteration with 6 elements in the fringe:
# [Node <(4, 5)>, Node <(6, 3)>, Node <(1, 1)>, Node <(1, 5)>, Node <(5, 5)>, Node <(6, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(4, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(4, 5)>]
# Successors: [[Node <(4, 4)>, Node <(5, 5)>, Node <(3, 5)>]]
# EVENT: new_iteration
# New iteration with 6 elements in the fringe:
# [Node <(6, 3)>, Node <(5, 5)>, Node <(1, 1)>, Node <(1, 5)>, Node <(3, 5)>, Node <(6, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 3)>]
# Successors: [[Node <(6, 2)>, Node <(6, 4)>]]
# EVENT: new_iteration
# New iteration with 6 elements in the fringe:
# [Node <(6, 2)>, Node <(5, 5)>, Node <(1, 1)>, Node <(1, 5)>, Node <(3, 5)>, Node <(6, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 2)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 2)>]
# Successors: [[Node <(6, 1)>, Node <(6, 3)>]]
# EVENT: new_iteration
# New iteration with 6 elements in the fringe:
# [Node <(1, 1)>, Node <(5, 5)>, Node <(3, 5)>, Node <(1, 5)>, Node <(6, 1)>, Node <(6, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(1, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(1, 1)>]
# Successors: [[Node <(1, 2)>, Node <(2, 1)>]]
# EVENT: new_iteration
# New iteration with 6 elements in the fringe:
# [Node <(3, 5)>, Node <(5, 5)>, Node <(6, 1)>, Node <(1, 5)>, Node <(2, 1)>, Node <(6, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(3, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(3, 5)>]
# Successors: [[Node <(4, 5)>, Node <(2, 5)>]]
# EVENT: new_iteration
# New iteration with 6 elements in the fringe:
# [Node <(6, 1)>, Node <(5, 5)>, Node <(2, 1)>, Node <(1, 5)>, Node <(6, 5)>, Node <(2, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 1)>]
# Successors: [[Node <(6, 2)>, Node <(5, 1)>]]
# EVENT: new_iteration
# New iteration with 6 elements in the fringe:
# [Node <(2, 1)>, Node <(5, 5)>, Node <(5, 1)>, Node <(1, 5)>, Node <(6, 5)>, Node <(2, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(2, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(2, 1)>]
# Successors: [[Node <(3, 1)>, Node <(1, 1)>]]
# EVENT: new_iteration
# New iteration with 6 elements in the fringe:
# [Node <(5, 1)>, Node <(5, 5)>, Node <(3, 1)>, Node <(1, 5)>, Node <(6, 5)>, Node <(2, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(5, 1)>
# Is goal!
# EVENT: finished
# Finished algorithm returning Node <(5, 1)>.
# Solution type: goal found
# Path from initial to goal: [(None, (3, 3)), ('right', (4, 3)), ('down', (4, 4)), ('right', (5, 4)), ('right', (6, 4)), ('up', (6, 3)), ('up', (6, 2)), ('up', (6, 1)), ('left', (5, 1))]
# ########
# #    P·#
# # ####·#
# #  T·#·#
# # ##···#
# #      #
# ########
# Total length of solution: 9
# Total cost of solution: 8.0
# max fringe size: 6
# visited nodes: 17
# iterations: 17
#
# Experimento con algoritmo <function astar at 0x000001E4E51A9F80>:
# After each step, a prompt will be shown.
# On the prompt, you can just press Enter to continue to the next step.
# But you can also have this commands:
# (write the command you want to use and then press Enter)
# * h: get help.
# * g PATH_TO_PNG_IMAGE: create png with graph of the current state.
# * e: run non-interactively to the end of the algorithm.
# * s: show statistics of the execution (max fringe size, visited nodes).
# * q: quit program.
# EVENT: started
# Algorithm just started.
# EVENT: new_iteration
# New iteration with 1 elements in the fringe:
# [Node <(3, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(3, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(3, 3)>]
# Successors: [[Node <(4, 3)>, Node <(2, 3)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(4, 3)>, Node <(2, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(4, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(4, 3)>]
# Successors: [[Node <(4, 4)>, Node <(3, 3)>]]
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(4, 4)>, Node <(2, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(4, 4)>
# Not goal
# EVENT: expanded
# Expanded [Node <(4, 4)>]
# Successors: [[Node <(4, 3)>, Node <(4, 5)>, Node <(5, 4)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(5, 4)>, Node <(2, 3)>, Node <(4, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(5, 4)>
# Not goal
# EVENT: expanded
# Expanded [Node <(5, 4)>]
# Successors: [[Node <(5, 5)>, Node <(6, 4)>, Node <(4, 4)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(2, 3)>, Node <(6, 4)>, Node <(5, 5)>, Node <(4, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(2, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(2, 3)>]
# Successors: [[Node <(3, 3)>, Node <(1, 3)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(5, 5)>, Node <(6, 4)>, Node <(4, 5)>, Node <(1, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(5, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(5, 5)>]
# Successors: [[Node <(5, 4)>, Node <(6, 5)>, Node <(4, 5)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(6, 4)>, Node <(4, 5)>, Node <(1, 3)>, Node <(6, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 4)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 4)>]
# Successors: [[Node <(6, 3)>, Node <(6, 5)>, Node <(5, 4)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(6, 3)>, Node <(4, 5)>, Node <(1, 3)>, Node <(6, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 3)>]
# Successors: [[Node <(6, 2)>, Node <(6, 4)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(6, 2)>, Node <(4, 5)>, Node <(1, 3)>, Node <(6, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 2)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 2)>]
# Successors: [[Node <(6, 1)>, Node <(6, 3)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(6, 1)>, Node <(4, 5)>, Node <(1, 3)>, Node <(6, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 1)>]
# Successors: [[Node <(6, 2)>, Node <(5, 1)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(5, 1)>, Node <(4, 5)>, Node <(1, 3)>, Node <(6, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(5, 1)>
# Is goal!
# EVENT: finished
# Finished algorithm returning Node <(5, 1)>.
# Solution type: goal found
# Path from initial to goal: [(None, (3, 3)), ('right', (4, 3)), ('down', (4, 4)), ('right', (5, 4)), ('right', (6, 4)), ('up', (6, 3)), ('up', (6, 2)), ('up', (6, 1)), ('left', (5, 1))]
# ########
# #    P·#
# # ####·#
# #  T·#·#
# # ##···#
# #      #
# ########
# Total length of solution: 9
# Total cost of solution: 8.0
# max fringe size: 4
# visited nodes: 11
# iterations: 11
